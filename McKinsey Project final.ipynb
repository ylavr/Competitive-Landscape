# %% [markdown]
# # SQL Project
# You were hired by Ironhack to perform an Analytics Consulting Project entitled: competitive landscape.
#
# Your mission is to create and populate an appropriate database with many coding schools that are our competition, as well as design an suitable queries that answer business questions of interest (to be defined by you)

# %% [markdown]
# **Suggested Steps in the Project:**
#
#
# *   Read this notebook and understand each function. Comment the code appropriately
#
# *   Populate the list of schools with a wider variety of schools (how are you going to get the school ID?)
#
# * Take a look at the obtained dataframes. What dimensions do you have? what keys do you have? how could the different dataframes be connected?
#
# * Go back to the drawing board and try to create an entity relationship diagram for tables available
#
# * Once you have the schemas you want, you will need to:
#   - create the suitable SQL queries to create the tables and populate them
#   - run these queries using the appropriate Python connectors
#
# * Bonus: How will this datamodel be updated in the future? Please write auxiliary functions that test the database for data quality issues. For example: how could you make sure you only include the most recent comments when you re-run the script?
#
#
# # Suggested Deliverables
#
# * 5-6 minute presentation of data model created, decision process and business analysis proposed
#
# * exported .sql file with the final schema
#
# * Supporting python files used to generate all logic
#
# * High level documentation explaining tables designed and focusing on update methods
#
# Crucial hint: check out the following tutorial:
# https://www.dataquest.io/blog/sql-insert-tutorial/

# %%
# you must populate this dict with the schools required -> try talking to the teaching team about this


schools = {   
'ironhack' : 10828,
'app-academy' : 10525,
'springboard' : 11035,
'actualize' : 10505,
'learningfuze': 10862,
'clarusway' : 11539,
'codesmith' : 10643,
'code-platoon' : 10627,
'knowledgehut' : 10846,
'udacity' : 11118,
'altcademy' : 10517,
'tech-elevator': 11056,
'codeworks' : 10650,
'4geeks-academy' : 10492,
'coding-temple' : 10664,
'devcodecamp' : 10703,
'nucamp' : 10923,
'tripleten' : 11225,
'skillcrush' : 11020,
'the-tech-academy' : 11091
}

import re
import pandas as pd
from pandas import json_normalize
import requests
import matplotlib.pyplot as plt
import seaborn as sns



def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])
  
    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
# could you write this as a list comprehension? ;)
comments = []

for school in schools.keys():
    print(school)
    comments.append(get_comments_school(school))

comments = pd.concat(comments)
# Out:
# ironhack
# app-academy
# springboard
# actualize
# learningfuze
# clarusway
# codesmith
# code-platoon
# knowledgehut
# udacity
# altcademy
# tech-elevator
# codeworks
# 4geeks-academy
# coding-temple
# devcodecamp
# nucamp
# tripleten
# skillcrush
# the-tech-academy

# %%
# # Set the option to display all columns
# pd.set_option('display.max_columns', None)

# %%
comments.head()
# Out:
#        id                            name  anonymous hostProgramName  \
# 0  309849                       Anonymous       True            None
# 1  309479                 Patrick Marques      False            None
# 2  308683  Harikrishnan Ramakrishnapillai      False            None
# 3  307433                    Sorin Tuinea      False            None
# 4  307350                    Kasia Luksza      False            None
#
#    graduatingYear  isAlumni         jobTitle  \
# 0          2024.0     False
# 1          2024.0     False  Project Manager
# 2          2023.0     False    Cybersecurity
# 3          2023.0     False     Data analyst
# 4          2023.0     False   UX/UI Designer
#
#                                              tagline  \
# 0                                     Data Analytics
# 1  An intense experience full of emotions but at ...
# 2                                     It was amazing
# 3                    I would definitely recommend it
# 4                Best learning experience of my life
#
#                                                 body  \
# 0  <span class="truncatable"><p></p><p>I just Fin...
# 1  <span class="truncatable"><p></p><p>Hello, my ...
# 2  <span class="truncatable"><p></p><p>I could fi...
# 3  <span class="truncatable"><p></p><p>I chose Ir...
# 4  <span class="truncatable"><p></p><p>Attending ...
#
#                                              rawBody  ...   queryDate  \
# 0  <p>I just Finished the my study , I did the Da...  ...  2024-04-03
# 1  <p>Hello, my name is Patrick Marques and I can...  ...  2024-03-19
# 2  <p>I could finish cybersecurity course within ...  ...  2024-02-15
# 3  <p>I chose Ironhack after reading a lot of rev...  ...  2023-12-22
# 4  <p>Attending this bootcamp was hands down the ...  ...  2023-12-19
#
#                     program             user overallScore comments overall  \
# 0  Data Analytics Part-Time  {'image': None}          3.3       []     4.0
# 1   Data Analytics Bootcamp  {'image': None}          4.0       []     4.0
# 2                      None  {'image': None}          4.3       []     4.0
# 3                      None  {'image': None}          5.0       []     5.0
# 4     UX/UI Design Bootcamp  {'image': None}          5.0       []     5.0
#
#   curriculum jobSupport                                        review_body  \
# 0        4.0        2.0  I just Finished the my study , I did the Data ...
# 1        4.0        4.0  Hello, my name is Patrick Marques and I can sa...
# 2        5.0        4.0  I could finish cybersecurity course within 3 m...
# 3        5.0        5.0  I chose Ironhack after reading a lot of review...
# 4        5.0        5.0  Attending this bootcamp was hands down the bes...
#
#      school
# 0  ironhack
# 1  ironhack
# 2  ironhack
# 3  ironhack
# 4  ironhack
#
# [5 rows x 21 columns]

# %%
from pandas import json_normalize

print('test')

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    price_min= data['content']['priceMin']
    price_max = data['content']['priceMax']

    price_df = pd.DataFrame([price_min, price_max]).T
    price_df.columns = ['price_min', 'price_max']

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    
    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school
    price_df['school'] = school
    

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id
    price_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df,price_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []
price_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d,e = get_school_info(school,id)
    
    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
    price_list.append(e)
# Out:
# test
# ironhack
# app-academy
# springboard
# actualize
# learningfuze
# clarusway
# codesmith
# code-platoon
# knowledgehut
# udacity
# altcademy
# tech-elevator
# codeworks
# 4geeks-academy
# coding-temple
# devcodecamp
# nucamp
# tripleten
# skillcrush
# the-tech-academy

# %%
price= pd.concat(price_list)

price['middle_price'] = (price["price_min"] + price['price_max'])/2

price
# Out:
#    price_min  price_max            school  school_id  middle_price
# 0       7500      13000          ironhack      10828       10250.0
# 0      20000      22000       app-academy      10525       21000.0
# 0        349       9900       springboard      11035        5124.5
# 0      16900      16900         actualize      10505       16900.0
# 0          0      15995      learningfuze      10862        7997.5
# 0        750      21500         clarusway      11539       11125.0
# 0        350      20925         codesmith      10643       10637.5
# 0      18000      18000      code-platoon      10627       18000.0
# 0        349       4999      knowledgehut      10846        2674.0
# 0        718       2154           udacity      11118        1436.0
# 0          0       2260         altcademy      10517        1130.0
# 0      16500      16500     tech-elevator      11056       16500.0
# 0       7800      10800         codeworks      10650        9300.0
# 0       3000      14999    4geeks-academy      10492        8999.5
# 0       5000      14995     coding-temple      10664        9997.5
# 0       9997      14997       devcodecamp      10703       12497.0
# 0        428       2805            nucamp      10923        1616.5
# 0       4900       9700         tripleten      11225        7300.0
# 0          0       2499        skillcrush      11020        1249.5
# 0       1800      14000  the-tech-academy      11091        7900.0

# %%
locations_list
# Out:
# [      id               description  country.id   country.name country.abbrev  \
#  0  15901           Berlin, Germany        57.0        Germany             DE
#  1  16022       Mexico City, Mexico        29.0         Mexico             MX
#  2  16086    Amsterdam, Netherlands        59.0    Netherlands             NL
#  3  16088         Sao Paulo, Brazil        42.0         Brazil             BR
#  4  16109             Paris, France        38.0         France             FR
#  5  16375  Miami, FL, United States         1.0  United States             US
#  6  16376             Madrid, Spain        12.0          Spain             ES
#  7  16377          Barcelona, Spain        12.0          Spain             ES
#  8  16709          Lisbon, Portugal        28.0       Portugal             PT
#  9  17233                    Online         NaN            NaN            NaN
#
#     city.id    city.name city.keyword  state.id state.name state.abbrev  \
#  0  31156.0       Berlin       berlin       NaN        NaN          NaN
#  1  31175.0  Mexico City  mexico-city       NaN        NaN          NaN
#  2  31168.0    Amsterdam    amsterdam       NaN        NaN          NaN
#  3  31121.0    Sao Paulo    sao-paulo       NaN        NaN          NaN
#  4  31136.0        Paris        paris       NaN        NaN          NaN
#  5     31.0        Miami        miami      11.0    Florida           FL
#  6  31052.0       Madrid       madrid       NaN        NaN          NaN
#  7  31170.0    Barcelona    barcelona       NaN        NaN          NaN
#  8  31075.0       Lisbon       lisbon       NaN        NaN          NaN
#  9      NaN          NaN          NaN       1.0     Online       Online
#
#    state.keyword    school  school_id
#  0           NaN  ironhack      10828
#  1           NaN  ironhack      10828
#  2           NaN  ironhack      10828
#  3           NaN  ironhack      10828
#  4           NaN  ironhack      10828
#  5       florida  ironhack      10828
#  6           NaN  ironhack      10828
#  7           NaN  ironhack      10828
#  8           NaN  ironhack      10828
#  9        online  ironhack      10828  ,
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  15862      Online         1     Online       Online        online
#
#          school  school_id
#  0  app-academy      10525  ,
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  16013      Online         1     Online       Online        online
#
#          school  school_id
#  0  springboard      11035  ,
#        id                 description  country.id   country.name  \
#  0  15703  Chicago, IL, United States         1.0  United States
#  1  16019                      Online         NaN            NaN
#
#    country.abbrev  state.id state.name state.abbrev state.keyword  city.id  \
#  0             US        15   Illinois           IL      illinois     39.0
#  1            NaN         1     Online       Online        online      NaN
#
#    city.name city.keyword     school  school_id
#  0   Chicago      chicago  actualize      10505
#  1       NaN          NaN  actualize      10505  ,
#        id                   description  country.id   country.name  \
#  0  16712     Irvine, CA, United States         1.0  United States
#  1  16806  San Diego, CA, United States         1.0  United States
#  2  16970                        Online         NaN            NaN
#
#    country.abbrev  state.id  state.name state.abbrev state.keyword  city.id  \
#  0             US         6  California           CA    california     24.0
#  1             US         6  California           CA    california     11.0
#  2            NaN         1      Online       Online        online      NaN
#
#     city.name city.keyword        school  school_id
#  0     Irvine       irvine  learningfuze      10862
#  1  San Diego    san-diego  learningfuze      10862
#  2        NaN          NaN  learningfuze      10862  ,
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  17789      Online         1     Online       Online        online
#
#        school  school_id
#  0  clarusway      11539  ,
#        id                       description  country.id   country.name  \
#  0  16002    Los Angeles, CA, United States         1.0  United States
#  1  16328  New York City, NY, United States         1.0  United States
#  2  16595                            Online         NaN            NaN
#  3  17438                Temporarily Online         1.0  United States
#
#    country.abbrev  state.id  state.name state.abbrev state.keyword  city.id  \
#  0             US       6.0  California           CA    california     10.0
#  1             US      34.0    New York           NY      new-york   1507.0
#  2            NaN       1.0      Online       Online        online      NaN
#  3             US       NaN         NaN          NaN           NaN  31234.0
#
#              city.name   city.keyword     school  school_id
#  0         Los Angeles    los-angeles  codesmith      10643
#  1                 NYC  new-york-city  codesmith      10643
#  2                 NaN            NaN  codesmith      10643
#  3  Temporarily Online    temp-online  codesmith      10643  ,
#        id                 description  country.id   country.name  \
#  0  15909  Chicago, IL, United States         1.0  United States
#  1  16764                      Online         NaN            NaN
#
#    country.abbrev  state.id state.name state.abbrev state.keyword  city.id  \
#  0             US        15   Illinois           IL      illinois     39.0
#  1            NaN         1     Online       Online        online      NaN
#
#    city.name city.keyword        school  school_id
#  0   Chicago      chicago  code-platoon      10627
#  1       NaN          NaN  code-platoon      10627  ,
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  15775      Online         1     Online       Online        online
#
#           school  school_id
#  0  knowledgehut      10846  ,
#        id description  state.id state.name state.abbrev state.keyword   school  \
#  0  15807      Online         1     Online       Online        online  udacity
#
#     school_id
#  0      11118  ,
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  16297      Online         1     Online       Online        online
#
#        school  school_id
#  0  altcademy      10517  ,
#        id                    description  country.id   country.name  \
#  0  16035   Cleveland, OH, United States         1.0  United States
#  1  16127    Columbus, OH, United States         1.0  United States
#  2  16143  Cincinnati, OH, United States         1.0  United States
#  3  16477  Pittsburgh, PA, United States         1.0  United States
#  4  17272                         Online         NaN            NaN
#  5  17722      Dallas, TX, United States         1.0  United States
#
#    country.abbrev  state.id    state.name state.abbrev state.keyword  city.id  \
#  0             US        37          Ohio           OH          ohio     71.0
#  1             US        37          Ohio           OH          ohio     70.0
#  2             US        37          Ohio           OH          ohio     72.0
#  3             US        40  Pennsylvania           PA  pennsylvania     78.0
#  4            NaN         1        Online       Online        online      NaN
#  5             US        45         Texas           TX         texas     83.0
#
#      city.name city.keyword         school  school_id
#  0   Cleveland    cleveland  tech-elevator      11056
#  1    Columbus     columbus  tech-elevator      11056
#  2  Cincinnati   cincinnati  tech-elevator      11056
#  3  Pittsburgh   pittsburgh  tech-elevator      11056
#  4         NaN          NaN  tech-elevator      11056
#  5      Dallas       dallas  tech-elevator      11056  ,
#        id       description  country.id country.name country.abbrev  city.id  \
#  0  16122  Barcelona, Spain        12.0        Spain             ES  31170.0
#  1  17049            Online         NaN          NaN            NaN      NaN
#  2  17122   Berlin, Germany        57.0      Germany             DE  31156.0
#  3  17126   London, England        61.0      England             GB  31176.0
#
#     city.name city.keyword  state.id state.name state.abbrev state.keyword  \
#  0  Barcelona    barcelona       NaN        NaN          NaN           NaN
#  1        NaN          NaN       1.0     Online       Online        online
#  2     Berlin       berlin       NaN        NaN          NaN           NaN
#  3     London       london       NaN        NaN          NaN           NaN
#
#        school  school_id
#  0  codeworks      10650
#  1  codeworks      10650
#  2  codeworks      10650
#  3  codeworks      10650  ,
#         id                 description  country.id   country.name  \
#  0   16054    Miami, FL, United States         1.0  United States
#  1   16758          Caracas, Venezuela        58.0      Venezuela
#  2   17370               Madrid, Spain        12.0          Spain
#  3   17805  Orlando, FL, United States         1.0  United States
#  4   17806        San Jose, Costa Rica        18.0     Costa Rica
#  5   17811         Montevideo, Uruguay        33.0        Uruguay
#  6   18220            Barcelona, Spain        12.0          Spain
#  7   18223                Milan, Italy        39.0          Italy
#  8   18224                 Rome, Italy        39.0          Italy
#  9   18225            Hamburg, Germany        57.0        Germany
#  10  18226             Berlin, Germany        57.0        Germany
#  11  18227             Dublin, Ireland        25.0        Ireland
#  12  18228            Lisbon, Portugal        28.0       Portugal
#  13  18229             Munich, Germany        57.0        Germany
#  14  18231             Santiago, Chile        22.0          Chile
#  15  18232            Bogota, Columbia        30.0       Colombia
#  16  18233         Mexico City, Mexico        29.0         Mexico
#  17  18234     Buenos Aires, Argentina        60.0      Argentina
#  18  18236         Panama City, Panama         1.0  United States
#  19  18237                  Lima, Peru       196.0           Peru
#  20  18238              Quito, Ecuador       113.0        Ecuador
#  21  18239             La Paz, Bolivia        83.0        Bolivia
#  22  18241             Toronto, Canada         2.0         Canada
#  23  18242               Malaga, Spain        12.0          Spain
#  24  18370                      Online         NaN            NaN
#  25  18371                 Atlanta, GA         1.0  United States
#  26  18372                 Houston, TX         1.0  United States
#  27  18373                 Chicago, IL         1.0  United States
#  28  18374             Los Angeles, CA         1.0  United States
#  29  18375                New York, NY         1.0  United States
#  30  18663                  Austin, TX         1.0  United States
#
#     country.abbrev  state.id  state.name state.abbrev state.keyword  city.id  \
#  0              US      11.0     Florida           FL       florida     31.0
#  1              VE       NaN         NaN          NaN           NaN  31159.0
#  2              ES       NaN         NaN          NaN           NaN  31052.0
#  3              US      11.0     Florida           FL       florida     33.0
#  4              CR       NaN         NaN          NaN           NaN  31236.0
#  5              UY       NaN         NaN          NaN           NaN  31089.0
#  6              ES       NaN         NaN          NaN           NaN  31170.0
#  7              IT       NaN         NaN          NaN           NaN  31107.0
#  8              IT       NaN         NaN          NaN           NaN  31180.0
#  9              DE       NaN         NaN          NaN           NaN  31222.0
#  10             DE       NaN         NaN          NaN           NaN  31156.0
#  11             IE       NaN         NaN          NaN           NaN  31099.0
#  12             PT       NaN         NaN          NaN           NaN  31075.0
#  13             DE       NaN         NaN          NaN           NaN  31158.0
#  14             CL       NaN         NaN          NaN           NaN  31067.0
#  15             CO       NaN         NaN          NaN           NaN  31078.0
#  16             MX       NaN         NaN          NaN           NaN  31175.0
#  17             AR       NaN         NaN          NaN           NaN  31171.0
#  18             US       NaN         NaN          NaN           NaN    806.0
#  19             PE       NaN         NaN          NaN           NaN  31256.0
#  20             EC       NaN         NaN          NaN           NaN  31235.0
#  21             BO       NaN         NaN          NaN           NaN  31300.0
#  22             CA       NaN         NaN          NaN           NaN  31152.0
#  23             ES       NaN         NaN          NaN           NaN  31298.0
#  24            NaN       1.0      Online       Online        online      NaN
#  25             US      12.0     Georgia           GA       georgia     36.0
#  26             US      45.0       Texas           TX         texas     81.0
#  27             US      15.0    Illinois           IL      illinois     39.0
#  28             US       6.0  California           CA    california     10.0
#  29             US      34.0    New York           NY      new-york   3619.0
#  30             US      45.0       Texas           TX         texas     84.0
#
#         city.name  city.keyword          school  school_id
#  0          Miami         miami  4geeks-academy      10492
#  1        Caracas       caracas  4geeks-academy      10492
#  2         Madrid        madrid  4geeks-academy      10492
#  3        Orlando       orlando  4geeks-academy      10492
#  4       San Jose      san-jose  4geeks-academy      10492
#  5     Montevideo    montevideo  4geeks-academy      10492
#  6      Barcelona     barcelona  4geeks-academy      10492
#  7          Milan         milan  4geeks-academy      10492
#  8           Rome          rome  4geeks-academy      10492
#  9        Hamburg       hamburg  4geeks-academy      10492
#  10        Berlin        berlin  4geeks-academy      10492
#  11        Dublin        dublin  4geeks-academy      10492
#  12        Lisbon        lisbon  4geeks-academy      10492
#  13        Munich        munich  4geeks-academy      10492
#  14      Santiago      santiago  4geeks-academy      10492
#  15        Bogota        bogota  4geeks-academy      10492
#  16   Mexico City   mexico-city  4geeks-academy      10492
#  17  Buenos Aires  buenos-aires  4geeks-academy      10492
#  18   Panama City   panama-city  4geeks-academy      10492
#  19          Lima          lima  4geeks-academy      10492
#  20         Quito         quito  4geeks-academy      10492
#  21        La Paz        la-paz  4geeks-academy      10492
#  22       Toronto       toronto  4geeks-academy      10492
#  23        Malaga  malaga-spain  4geeks-academy      10492
#  24           NaN           NaN  4geeks-academy      10492
#  25       Atlanta       atlanta  4geeks-academy      10492
#  26       Houston       houston  4geeks-academy      10492
#  27       Chicago       chicago  4geeks-academy      10492
#  28   Los Angeles   los-angeles  4geeks-academy      10492
#  29     New  York      new-york  4geeks-academy      10492
#  30        Austin        austin  4geeks-academy      10492  ,
#        id                    description  country.id   country.name  \
#  0  15875      Austin, TX, United States         1.0  United States
#  1  15876      Dallas, TX, United States         1.0  United States
#  2  16003     Chicago, IL, United States         1.0  United States
#  3  16140      Boston, MA, United States         1.0  United States
#  4  16436  Washington, DC, United States         1.0  United States
#  5  16799                         Online         NaN            NaN
#
#    country.abbrev  state.id            state.name state.abbrev  \
#  0             US        45                 Texas           TX
#  1             US        45                 Texas           TX
#  2             US        15              Illinois           IL
#  3             US        23         Massachusetts           MA
#  4             US        10  District of Columbia           DC
#  5            NaN         1                Online       Online
#
#            state.keyword  city.id        city.name   city.keyword  \
#  0                 texas     84.0           Austin         austin
#  1                 texas     83.0           Dallas         dallas
#  2              illinois     39.0          Chicago        chicago
#  3         massachusetts     47.0           Boston         boston
#  4  district-of-columbia    775.0  Washington D.C.  washington-dc
#  5                online      NaN              NaN            NaN
#
#            school  school_id
#  0  coding-temple      10664
#  1  coding-temple      10664
#  2  coding-temple      10664
#  3  coding-temple      10664
#  4  coding-temple      10664
#  5  coding-temple      10664  ,
#        id                   description  country.id   country.name  \
#  0  16089  Milwaukee, WI, United States         1.0  United States
#  1  17420                        Online         NaN            NaN
#
#    country.abbrev  state.id state.name state.abbrev state.keyword  city.id  \
#  0             US        51  Wisconsin           WI     wisconsin     98.0
#  1            NaN         1     Online       Online        online      NaN
#
#     city.name city.keyword       school  school_id
#  0  Milwaukee    milwaukee  devcodecamp      10703
#  1        NaN          NaN  devcodecamp      10703  ,
#         id                    description  state.id            state.name  \
#  0   15709                         Online       1.0                Online
#  1   16463     Seattle, WA, United States      49.0            Washington
#  2   16730      Tacoma, WA, United States      49.0            Washington
#  3   16731  Marysville, WA, United States      49.0            Washington
#  4   16732     Spokane, WA, United States      49.0            Washington
#  ..    ...                            ...       ...                   ...
#  88  16903       Tulsa, OK, United States      38.0              Oklahoma
#  89  16904  Tuscaloosa, AL, United States       2.0               Alabama
#  90  16905  Washington, DC, United States      10.0  District of Columbia
#  91  16906  Wilmington, DE, United States       9.0              Delaware
#  92  16907          Wales, United Kingdom       NaN                   NaN
#
#     state.abbrev         state.keyword  country.id    country.name  \
#  0        Online                online         NaN             NaN
#  1            WA            washington         1.0   United States
#  2            WA            washington         1.0   United States
#  3            WA            washington         1.0   United States
#  4            WA            washington         1.0   United States
#  ..          ...                   ...         ...             ...
#  88           OK              oklahoma         1.0   United States
#  89           AL               alabama         1.0   United States
#  90           DC  district-of-columbia         1.0   United States
#  91           DE              delaware         1.0   United States
#  92          NaN                   NaN        11.0  United Kingdom
#
#     country.abbrev  city.id        city.name   city.keyword  school  school_id
#  0             NaN      NaN              NaN            NaN  nucamp      10923
#  1              US     97.0          Seattle        seattle  nucamp      10923
#  2              US   1196.0           Tacoma         tacoma  nucamp      10923
#  3              US  30455.0       Marysville     marysville  nucamp      10923
#  4              US   1195.0          Spokane        spokane  nucamp      10923
#  ..            ...      ...              ...            ...     ...        ...
#  88             US     75.0            Tulsa          tulsa  nucamp      10923
#  89             US    697.0       Tuscaloosa     tuscaloosa  nucamp      10923
#  90             US    775.0  Washington D.C.  washington-dc  nucamp      10923
#  91             US    774.0       Wilmington     wilmington  nucamp      10923
#  92             GB  31092.0            Wales          wales  nucamp      10923
#
#  [93 rows x 14 columns],
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  17154      Online         1     Online       Online        online
#
#        school  school_id
#  0  tripleten      11225  ,
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  15796      Online         1     Online       Online        online
#
#         school  school_id
#  0  skillcrush      11020  ,
#        id                  description  country.id   country.name  \
#  0  15729  Portland, OR, United States         1.0  United States
#  1  16404                       Online         NaN            NaN
#
#    country.abbrev  state.id state.name state.abbrev state.keyword  city.id  \
#  0             US        39     Oregon           OR        oregon     76.0
#  1            NaN         1     Online       Online        online      NaN
#
#    city.name city.keyword            school  school_id
#  0  Portland     portland  the-tech-academy      11091
#  1       NaN          NaN  the-tech-academy      11091  ]

# %%
locations = pd.concat(locations_list)
locations.head()
# Out:
#       id             description  country.id country.name country.abbrev  \
# 0  15901         Berlin, Germany        57.0      Germany             DE
# 1  16022     Mexico City, Mexico        29.0       Mexico             MX
# 2  16086  Amsterdam, Netherlands        59.0  Netherlands             NL
# 3  16088       Sao Paulo, Brazil        42.0       Brazil             BR
# 4  16109           Paris, France        38.0       France             FR
#
#    city.id    city.name city.keyword  state.id state.name state.abbrev  \
# 0  31156.0       Berlin       berlin       NaN        NaN          NaN
# 1  31175.0  Mexico City  mexico-city       NaN        NaN          NaN
# 2  31168.0    Amsterdam    amsterdam       NaN        NaN          NaN
# 3  31121.0    Sao Paulo    sao-paulo       NaN        NaN          NaN
# 4  31136.0        Paris        paris       NaN        NaN          NaN
#
#   state.keyword    school  school_id
# 0           NaN  ironhack      10828
# 1           NaN  ironhack      10828
# 2           NaN  ironhack      10828
# 3           NaN  ironhack      10828
# 4           NaN  ironhack      10828

# %%
locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 173 entries, 0 to 1
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              173 non-null    int64
#  1   description     173 non-null    object
#  2   country.id      153 non-null    float64
#  3   country.name    153 non-null    object
#  4   country.abbrev  153 non-null    object
#  5   city.id         153 non-null    float64
#  6   city.name       153 non-null    object
#  7   city.keyword    153 non-null    object
#  8   state.id        137 non-null    float64
#  9   state.name      137 non-null    object
#  10  state.abbrev    137 non-null    object
#  11  state.keyword   137 non-null    object
#  12  school          173 non-null    object
#  13  school_id       173 non-null    int64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 20.3+ KB

# %%
courses = pd.concat(courses_list)
courses
courses['courses'].value_counts()
# Out:
# courses
# Data Science                                                 2
# Cyber Security Bootcamp                                      1
# Ai and Machine Learning Full-Stack Program                   1
# Full-stack Web Development                                   1
# Full-stack Web Development with Data Science & Applied AI    1
#                                                             ..
# Software Development Engineer in Test (SDET)                 1
# NYC Onsite Immersive                                         1
# CS Prep                                                      1
# Full-Time Remote Software Engineering Immersive              1
# Self-Paced UI/UX Designer Boot Camp                          1
# Name: count, Length: 181, dtype: int64

# %%
badges = pd.concat(badges_list)
badges.head()
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
#
#                                          description       school  school_id
# 0          <p>School offers fully online courses</p>     ironhack      10828
# 1  <p>School publishes a third-party verified out...     ironhack      10828
# 2  <p>School offers part-time and evening classes...     ironhack      10828
# 0          <p>School offers fully online courses</p>  app-academy      10525
# 1  <p>School offers part-time and evening classes...  app-academy      10525

# %%
# any data cleaning still missing here? take a look at the description
schools = pd.concat(schools_list)
schools.head()
# Out:
#                                              website  \
# 0                                www.ironhack.com/en
# 0                                      appacademy.io
# 0  www.springboard.com/?utm_source=switchup&utm_m...
# 0  anyonecanlearntocode.com/?utm_source=switchup&...
# 0                                   learningfuze.com
#
#                                          description  \
# 0  <span class="truncatable"><p>Ironhack is a glo...
# 0  <span class="truncatable"><p>Founded in 2012, ...
# 0  <span class="truncatable"><p>Springboard is an...
# 0  <span class="truncatable"><p>Actualize is a co...
# 0  <span class="truncatable"><p>LearningFuze is a...
#
#                                              LogoUrl        school  school_id
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...      ironhack      10828
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...   app-academy      10525
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...   springboard      11035
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...     actualize      10505
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  learningfuze      10862

# %% [markdown]
# ---

# %% [markdown]
# # Data Preparation and Cleaning

# %% [markdown]
# ### Drop useless/duplicate columns in the 'comments' dataframe

# %%
comments.drop(columns=['comments', 'body', 'rawBody', 'user'], inplace=True)

# %%
comments.head()
# Out:
#        id                            name  anonymous hostProgramName  \
# 0  309849                       Anonymous       True            None
# 1  309479                 Patrick Marques      False            None
# 2  308683  Harikrishnan Ramakrishnapillai      False            None
# 3  307433                    Sorin Tuinea      False            None
# 4  307350                    Kasia Luksza      False            None
#
#    graduatingYear  isAlumni         jobTitle  \
# 0          2024.0     False
# 1          2024.0     False  Project Manager
# 2          2023.0     False    Cybersecurity
# 3          2023.0     False     Data analyst
# 4          2023.0     False   UX/UI Designer
#
#                                              tagline   createdAt   queryDate  \
# 0                                     Data Analytics    4/3/2024  2024-04-03
# 1  An intense experience full of emotions but at ...   3/19/2024  2024-03-19
# 2                                     It was amazing   2/15/2024  2024-02-15
# 3                    I would definitely recommend it  12/22/2023  2023-12-22
# 4                Best learning experience of my life  12/19/2023  2023-12-19
#
#                     program overallScore overall curriculum jobSupport  \
# 0  Data Analytics Part-Time          3.3     4.0        4.0        2.0
# 1   Data Analytics Bootcamp          4.0     4.0        4.0        4.0
# 2                      None          4.3     4.0        5.0        4.0
# 3                      None          5.0     5.0        5.0        5.0
# 4     UX/UI Design Bootcamp          5.0     5.0        5.0        5.0
#
#                                          review_body    school
# 0  I just Finished the my study , I did the Data ...  ironhack
# 1  Hello, my name is Patrick Marques and I can sa...  ironhack
# 2  I could finish cybersecurity course within 3 m...  ironhack
# 3  I chose Ironhack after reading a lot of review...  ironhack
# 4  Attending this bootcamp was hands down the bes...  ironhack

# %%
comments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9768 entries, 0 to 354
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               9768 non-null   int64
#  1   name             9768 non-null   object
#  2   anonymous        9768 non-null   bool
#  3   hostProgramName  3474 non-null   object
#  4   graduatingYear   9731 non-null   float64
#  5   isAlumni         9768 non-null   bool
#  6   jobTitle         6127 non-null   object
#  7   tagline          9767 non-null   object
#  8   createdAt        9768 non-null   object
#  9   queryDate        9768 non-null   object
#  10  program          8581 non-null   object
#  11  overallScore     9757 non-null   object
#  12  overall          9755 non-null   object
#  13  curriculum       9568 non-null   object
#  14  jobSupport       8753 non-null   object
#  15  review_body      9768 non-null   object
#  16  school           9768 non-null   object
# dtypes: bool(2), float64(1), int64(1), object(13)
# memory usage: 1.2+ MB

# %% [markdown]
# ### Change data type of columns graduatingYear(from float to int)

# %%
comments['graduatingYear'].fillna(0, inplace=True)

comments['graduatingYear'] = comments['graduatingYear'].astype(int)

# %%
comments['createdAt'] = pd.to_datetime(comments['createdAt'], errors='coerce')

# %% [markdown]
# ### Drop useless/duplicate columns in the 'locations' dataframe

# %%
locations.drop(columns=['country.id', 'country.abbrev', 'city.id', 'city.keyword','state.id','state.abbrev','state.keyword'], inplace=True)

# %% [markdown]
# ### Rename columns in the "locations" dataframe in order to follow name_convention:

# %%
locations = locations.reset_index(drop = True)
locations.rename(columns = {'country.name' : 'country_name', 'city.name':'city_name', 'state.name':'state_name'}, inplace = True)

# %% [markdown]
# ### Fill cells NaN with "Online"

# %%
index = locations[(locations["country_name"].isna()) & (locations["city_name"].isna())].index

locations.loc[index, ['country_name', 'city_name']] = locations.loc[index, ['country_name', 'city_name']].fillna('Online')
    
locations.head()
# Out:
#       id             description country_name    city_name state_name  \
# 0  15901         Berlin, Germany      Germany       Berlin        NaN
# 1  16022     Mexico City, Mexico       Mexico  Mexico City        NaN
# 2  16086  Amsterdam, Netherlands  Netherlands    Amsterdam        NaN
# 3  16088       Sao Paulo, Brazil       Brazil    Sao Paulo        NaN
# 4  16109           Paris, France       France        Paris        NaN
#
#      school  school_id
# 0  ironhack      10828
# 1  ironhack      10828
# 2  ironhack      10828
# 3  ironhack      10828
# 4  ironhack      10828

# %% [markdown]
# ### Drop useless/duplicate columns in the 'schools' dataframe and index

# %%
schools = schools.reset_index(drop = True)
schools.drop(columns = ['LogoUrl'],inplace = True)

# %% [markdown]
# ### Clean the string in the description column of 'schools' and 'badges' tables

# %%
schools['description'] = schools['description'].str.replace('<span class="truncatable"><p>', '')
schools['description'] = schools['description'].str.replace('<span class="read-more-text">... <a class="read-more-button">Read More</a></span><span class="read-more" style="display:none;">', '')
schools['description'] = schools['description'].str.replace('</p><p>', ' ')
schools['description'] = schools['description'].str.replace('</span></p><p>', ' ')
schools['description'] = schools['description'].str.replace("</p><span class='read-less-text' style='display:none;'><a class='read-less-button'>Read Less</a></span></span>", '')
schools['description'] = schools['description'].str.replace('</span>', '')

# %%
locations['city_name'] = locations['city_name'].str.replace('NYC', 'New York')
locations['city_name'] = locations['city_name'].str.replace('New  York', 'New York')
locations['city_name'] = locations['city_name'].str.replace('Temporarily Online', 'Online')

# %%
badges['description'] = badges['description'].str.replace('<p>', '')
badges['description'] = badges['description'].str.replace('</p>', '')

# %%
badges = badges.reset_index(drop = True)

# %% [markdown]
# ### Adding missing values for comments

# %%
comments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9768 entries, 0 to 354
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               9768 non-null   int64
#  1   name             9768 non-null   object
#  2   anonymous        9768 non-null   bool
#  3   hostProgramName  3474 non-null   object
#  4   graduatingYear   9768 non-null   int32
#  5   isAlumni         9768 non-null   bool
#  6   jobTitle         6127 non-null   object
#  7   tagline          9767 non-null   object
#  8   createdAt        9768 non-null   datetime64[ns]
#  9   queryDate        9768 non-null   object
#  10  program          8581 non-null   object
#  11  overallScore     9757 non-null   object
#  12  overall          9755 non-null   object
#  13  curriculum       9568 non-null   object
#  14  jobSupport       8753 non-null   object
#  15  review_body      9768 non-null   object
#  16  school           9768 non-null   object
# dtypes: bool(2), datetime64[ns](1), int32(1), int64(1), object(12)
# memory usage: 1.2+ MB

# %%
# # Set the option to display all rows
# pd.set_option('display.max_rows', None)

# %%
comments_filtered = comments[(comments["hostProgramName"].isna())&(comments["program"].notna())]
comments_filtered["program"].value_counts()
# Out:
# program
#                                                                             592
# UI/UX Design Career Track                                                   305
# Software Engineer Track: In-Person                                          296
# Data Analytics Career Track                                                 187
# Actualize Coding Bootcamp: Online Live                                      187
#                                                                            ...
# Java Bootcamp - Spring 2020 (PHL) 1/27 - 5/1                                  1
# Java Bootcamp - Fall 2020 (CLE, CBUS, CINCY, DET, PGH, PHL) 9/14 - 12/18      1
# Java/.NET Bootcamp - Spring 2020 (CLE | CBUS | CINCY | DET | PGH)             1
# Java/.NET Bootcamp                                                            1
# Computer Vision                                                               1
# Name: count, Length: 195, dtype: int64

# %%
index = comments[comments["hostProgramName"].isna()].index

comments.loc[index, ["hostProgramName"]] = comments.loc[index, ["hostProgramName"]].fillna('Not available')

comments.head(5)
# Out:
#        id                            name  anonymous hostProgramName  \
# 0  309849                       Anonymous       True   Not available
# 1  309479                 Patrick Marques      False   Not available
# 2  308683  Harikrishnan Ramakrishnapillai      False   Not available
# 3  307433                    Sorin Tuinea      False   Not available
# 4  307350                    Kasia Luksza      False   Not available
#
#    graduatingYear  isAlumni         jobTitle  \
# 0            2024     False
# 1            2024     False  Project Manager
# 2            2023     False    Cybersecurity
# 3            2023     False     Data analyst
# 4            2023     False   UX/UI Designer
#
#                                              tagline  createdAt   queryDate  \
# 0                                     Data Analytics 2024-04-03  2024-04-03
# 1  An intense experience full of emotions but at ... 2024-03-19  2024-03-19
# 2                                     It was amazing 2024-02-15  2024-02-15
# 3                    I would definitely recommend it 2023-12-22  2023-12-22
# 4                Best learning experience of my life 2023-12-19  2023-12-19
#
#                     program overallScore overall curriculum jobSupport  \
# 0  Data Analytics Part-Time          3.3     4.0        4.0        2.0
# 1   Data Analytics Bootcamp          4.0     4.0        4.0        4.0
# 2                      None          4.3     4.0        5.0        4.0
# 3                      None          5.0     5.0        5.0        5.0
# 4     UX/UI Design Bootcamp          5.0     5.0        5.0        5.0
#
#                                          review_body    school
# 0  I just Finished the my study , I did the Data ...  ironhack
# 1  Hello, my name is Patrick Marques and I can sa...  ironhack
# 2  I could finish cybersecurity course within 3 m...  ironhack
# 3  I chose Ironhack after reading a lot of review...  ironhack
# 4  Attending this bootcamp was hands down the bes...  ironhack

# %%
# Define the categories and corresponding keywords for categorization:
categories = {
    'Software Engineering': ['Software Engineering','Full Stack Development','Actualize Coding Bootcamp','Coding 101','Ruby on Rails','Software Engineer Track','AWS Cloud Engineer','AWS Solutions Architect','DevOps Engineer','Cloud for Tester','Salesforce Administrator & Developer','JavaScript for Beginners','Front End Development','Software Development Engineer','Full Time JavaScript','AI Engineer','C++','Full stack','Backend','Machine Learning Engineering','Java/.NET,','C#',"Python",'Game Developer','React','.NET','JAVA/.NET','Java','Data Engineer','Cloud','Al ', 'Engineer','Software','Full-Stack development','Deep','Computer Science','Machine Learning',' Programming','Vision','Frontend','Front End Web and Mobile Development','Full Stack Web and Mobile App Development','Front End Web and Mobile Development'],
    'UX/UI Design': ['UX/UI','UI/UX','UX'],
    'Data Science': ['Data Science','Machine Learning/Deep Learning','Scientist','Data Structures and Algorithms'],
    'Web Development': ['Web Development','WebDesignium','Web Developer','Web'],
    'Data Analytics': ['Data Analytics','Data Analyst','Intelligence Analyst',"Business"],
    'Mobile Development': ['Mobile Development','Android','iOS'],
    'Bootcamp Prep': ['Bootcamp Prep','CS Prep'],
    'Digital Marketing': ['Digital Marketing', 'Internet Marketing','Marleting','Marketing Analytic','Digital Marketing Career Track'],
    'Product Management': ['Product Management','Tech Sales Career Track'],
    'Blockchain and Crypto': ['Blockchain', 'Crypto','Bitcoin 101'],
    'Cybersecurity': ['Cybersecurity', 'Cyber Security'],
    'IT Training': ['IT Training']
}

# Define the function to categorize programs
def categorize_program(program):
    if program is not None:
        for category, keywords in categories.items():
            for keyword in keywords:
                if keyword.lower() in program.lower():
                    return category
    return 'Other'

# Apply the function to create a new column 'Program_category'
comments['program_category'] = comments['program'].apply(categorize_program)

# Display the DataFrame
comments.head()
# Out:
#        id                            name  anonymous hostProgramName  \
# 0  309849                       Anonymous       True   Not available
# 1  309479                 Patrick Marques      False   Not available
# 2  308683  Harikrishnan Ramakrishnapillai      False   Not available
# 3  307433                    Sorin Tuinea      False   Not available
# 4  307350                    Kasia Luksza      False   Not available
#
#    graduatingYear  isAlumni         jobTitle  \
# 0            2024     False
# 1            2024     False  Project Manager
# 2            2023     False    Cybersecurity
# 3            2023     False     Data analyst
# 4            2023     False   UX/UI Designer
#
#                                              tagline  createdAt   queryDate  \
# 0                                     Data Analytics 2024-04-03  2024-04-03
# 1  An intense experience full of emotions but at ... 2024-03-19  2024-03-19
# 2                                     It was amazing 2024-02-15  2024-02-15
# 3                    I would definitely recommend it 2023-12-22  2023-12-22
# 4                Best learning experience of my life 2023-12-19  2023-12-19
#
#                     program overallScore overall curriculum jobSupport  \
# 0  Data Analytics Part-Time          3.3     4.0        4.0        2.0
# 1   Data Analytics Bootcamp          4.0     4.0        4.0        4.0
# 2                      None          4.3     4.0        5.0        4.0
# 3                      None          5.0     5.0        5.0        5.0
# 4     UX/UI Design Bootcamp          5.0     5.0        5.0        5.0
#
#                                          review_body    school  \
# 0  I just Finished the my study , I did the Data ...  ironhack
# 1  Hello, my name is Patrick Marques and I can sa...  ironhack
# 2  I could finish cybersecurity course within 3 m...  ironhack
# 3  I chose Ironhack after reading a lot of review...  ironhack
# 4  Attending this bootcamp was hands down the bes...  ironhack
#
#   program_category
# 0   Data Analytics
# 1   Data Analytics
# 2            Other
# 3            Other
# 4     UX/UI Design

# %%
# Group by 'program' and 'hostProgramName', then aggregate with the count of 'id' for check:
grouped_comments = comments.groupby(["school",'hostProgramName','program_category','program']).agg({'id': 'count'}).reset_index()
grouped_comments
# Out:
#              school       hostProgramName      program_category  \
# 0    4geeks-academy         Not available                 Other
# 1    4geeks-academy         Not available  Software Engineering
# 2    4geeks-academy         Not available  Software Engineering
# 3    4geeks-academy  Software Engineering                 Other
# 4    4geeks-academy  Software Engineering  Software Engineering
# ..              ...                   ...                   ...
# 350         udacity    Product Management  Software Engineering
# 351         udacity  Software Engineering                 Other
# 352         udacity  Software Engineering       Web Development
# 353         udacity          UX/UI Design                 Other
# 354         udacity          UX/UI Design          UX/UI Design
#
#                                        program   id
# 0                                                19
# 1              Full Stack Software Development   36
# 2    Full Stack Software Development Part Time   77
# 3                                                14
# 4              Full Stack Software Development   12
# ..                                         ...  ...
# 350                         Al Product Manager    4
# 351                                             106
# 352                    Front End Web Developer  170
# 353                                               5
# 354                                UX Designer    3
#
# [355 rows x 5 columns]

# %%
# Define the function to update Program_category based on conditions where we alredy had host program name:
def update_program_category(row):
    if row['program_category'] == 'Other' and row['hostProgramName'] != "Not available":
        return row['hostProgramName']
    return row['program_category']

# Apply the function to update 'Program_category'
comments['program_category'] = comments.apply(update_program_category, axis=1)

# %%
comments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9768 entries, 0 to 354
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                9768 non-null   int64
#  1   name              9768 non-null   object
#  2   anonymous         9768 non-null   bool
#  3   hostProgramName   9768 non-null   object
#  4   graduatingYear    9768 non-null   int32
#  5   isAlumni          9768 non-null   bool
#  6   jobTitle          6127 non-null   object
#  7   tagline           9767 non-null   object
#  8   createdAt         9768 non-null   datetime64[ns]
#  9   queryDate         9768 non-null   object
#  10  program           8581 non-null   object
#  11  overallScore      9757 non-null   object
#  12  overall           9755 non-null   object
#  13  curriculum        9568 non-null   object
#  14  jobSupport        8753 non-null   object
#  15  review_body       9768 non-null   object
#  16  school            9768 non-null   object
#  17  program_category  9768 non-null   object
# dtypes: bool(2), datetime64[ns](1), int32(1), int64(1), object(13)
# memory usage: 1.5+ MB

# %%
# # Group by 'program_category' then aggregate with the count of 'id' for check:
# grouped_comments = comments.groupby(['program_category']).agg({'id': 'count', 'overallScore': 'mean'}).reset_index()
# grouped_comments.head(10)

# %% [markdown]
# ### Add additional table with population

# %%
population = pd.read_csv("D:\IronHack\Study\Bootcamp\Project_03\geonames-all-cities-with-a-population-1000.csv", sep=';')

# %%
population.columns
# Out:
# Index(['Geoname ID', 'Name', 'ASCII Name', 'Alternate Names', 'Feature Class',
#        'Feature Code', 'Country Code', 'Country name EN', 'Country Code 2',
#        'Admin1 Code', 'Admin2 Code', 'Admin3 Code', 'Admin4 Code',
#        'Population', 'Elevation', 'DIgital Elevation Model', 'Timezone',
#        'Modification date', 'LABEL EN', 'Coordinates'],
#       dtype='object')

# %%
population.drop(columns=['Geoname ID', 'Alternate Names', 'Feature Class',
       'Feature Code', 'Country Code', 'Country Code 2',
       'Admin1 Code', 'Admin2 Code', 'Admin3 Code', 'Admin4 Code',
        'Elevation', 'DIgital Elevation Model', 'Timezone',
       'Modification date', 'LABEL EN', 'Coordinates'], inplace=True)

# %%
population.rename(columns = {'ASCII Name' : 'city_name', 'Country name EN':'country'}, inplace = True)

# %%
population
# Out:
#                      Name          city_name        country  Population
# 0       Heist-op-den-Berg  Heist-op-den-Berg        Belgium       37873
# 1                Harchies           Harchies        Belgium        1918
# 2               Florennes          Florennes        Belgium       10723
# 3                 Fleurus            Fleurus        Belgium       22080
# 4                  Eugies             Eugies        Belgium        3160
# ...                   ...                ...            ...         ...
# 147038         Hoegaarden         Hoegaarden        Belgium        3226
# 147039           Herchies           Herchies        Belgium        2480
# 147040           Hemiksem           Hemiksem        Belgium        9504
# 147041           Tapéguhé           Tapeguhe  Côte d'Ivoire        3700
# 147042            Sirihio            Sirihio  Côte d'Ivoire        3258
#
# [147043 rows x 4 columns]

# %% [markdown]
# ----

# %% [markdown]
# # Install and import nescessary modules

# %%
#!pip install mysql-connector-python

# %%
#!pip install pymysql

# %%
import mysql.connector
import getpass
import pymysql
from sqlalchemy import create_engine

# %% [markdown]
# ---

# %% [markdown]
# # Your MySQL Workbench password

# %%
saved_pass = getpass.getpass()

# %% [markdown]
# ---

# %% [markdown]
# # Set up a connection and make a cursor

# %% [markdown]
# ### Change the details for your device

# %%
connection = pymysql.connect(host= '127.0.0.1',
                         user='root',
                         password=saved_pass,
                         database='sakila',
                         port=3306)

# %%
cursor = connection.cursor()

# %% [markdown]
# ---

# %% [markdown]
# # Create a new database

# %%
# Create a new database

query = (""" CREATE DATABASE IF NOT EXISTS coding_schools """)

cursor.execute(query)
# Out:
# 1

# %% [markdown]
# ---

# %% [markdown]
# # Upload all the tables to your new dataframe

# %% [markdown]
# ### Create 'sqlalchemy' engine and again adjust the details for your device

# %%
engine = create_engine("mysql+pymysql://{user}:{password}@127.0.0.1/{database}"
                       .format(user="root",
                               password=saved_pass,
                               database="coding_schools"))

# %%
import sqlalchemy
sqlalchemy.__version__
# Out:
# '2.0.30'

# %% [markdown]
# ### Upload the tables

# %%
comments.to_sql('comments', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 9768

# %%
badges.to_sql('badges', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 55

# %%
schools.to_sql('schools', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 20

# %%
locations.to_sql('locations', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 173

# %%
courses.to_sql('courses', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 182

# %%
population.to_sql('population', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 147043

# %%
price.to_sql('price', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 20

# %% [markdown]
# ---

# %% [markdown]
# ## Visuals

# %%
learningfuze_count = comments[comments['school']=='learningfuze']

# %%
ironhack_count = comments[comments['school']=='ironhack']

# %%
comments['jobSupport'] = comments['jobSupport'].astype(float)
comments['overallScore'] = comments['overallScore'].astype(float)
comments['curriculum'] = comments['curriculum'].astype(float)

# %%
grouped_schools = comments.groupby('school').agg({'jobSupport': 'mean',
                                                 'overallScore': 'mean',
                                                 'curriculum': 'mean'}).reset_index()
grouped_schools
# Out:
#               school  jobSupport  overallScore  curriculum
# 0     4geeks-academy    4.840909      4.881215    4.898876
# 1          actualize    4.780543      4.865751    4.870897
# 2          altcademy    4.128571      4.701429    4.803828
# 3        app-academy    4.499083      4.600836    4.584525
# 4          clarusway    4.895833      4.908642    4.917695
# 5       code-platoon    4.931624      4.935897    4.897436
# 6          codesmith    4.890365      4.906158    4.900602
# 7          codeworks    4.913978      4.904737    4.867725
# 8      coding-temple    4.861446      4.884000    4.895349
# 9        devcodecamp    4.818182      4.841026    4.817680
# 10          ironhack    4.686495      4.732919    4.708831
# 11      knowledgehut    3.600000      4.892174    4.900000
# 12      learningfuze    4.987952      4.984659    4.982659
# 13            nucamp    3.876712      4.467075    4.614754
# 14        skillcrush    4.597826      4.687500    4.737864
# 15       springboard    4.503932      4.592883    4.576343
# 16     tech-elevator    4.899083      4.903913    4.881279
# 17  the-tech-academy    4.824503      4.773164    4.604502
# 18         tripleten    4.680000      4.800926    4.828704
# 19           udacity    4.062229      4.392669    4.546686

# %%
top_curriculum = grouped_schools.sort_values(by='curriculum', ascending=False)

# %%
top_overall = grouped_schools.sort_values(by='overallScore', ascending=False)

# %%
top_job_support = grouped_schools.sort_values(by='jobSupport', ascending=False)

# %%
top_curriculum
school_name_c = top_curriculum.iloc[:5]['school']
curriculum_rating = top_curriculum.iloc[:5]['curriculum']

# %%
top_overall
school_name_o = top_overall.iloc[:5]['school']
overall_rating = top_overall.iloc[:5]['overallScore']

# %%
top_job_support
school_name_j = top_job_support.iloc[:5]['school']
job_support_rating = top_job_support.iloc[:5]['jobSupport']

# %%
sns.set(rc={'figure.figsize':(12,5)})
sns.set_style("whitegrid")
ax = sns.countplot(x = 'graduatingYear',data = comments, width=0.3)
for bars in ax.containers:
    ax.bar_label(bars)
    
plt.xlabel('Graduating Year')
plt.ylabel('Number of Entries')
plt.title('Total number of entries per graduation year')

#plt.savefig('total_count.png')

plt.show()

# %%
grouped_schools[grouped_schools['school'] == 'ironhack']
# Out:
#       school  jobSupport  overallScore  curriculum
# 10  ironhack    4.686495      4.732919    4.708831

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(10, 4))
sns.barplot(x=school_name_j, y=job_support_rating, data=grouped_schools, palette='Set2', width=0.65)

plt.axhline(4.6,  linestyle='--', linewidth=2, label='Ironhack Average Rating')
plt.legend()

# Set labels and title
#plt.xticks(rotation=45, ha='right')
plt.xlabel('Job Support Rating')
plt.ylabel('School Name')
plt.title('Top 5 Job Support Rating by School')

plt.savefig('job_rating_ih.png')

# Show plot
plt.show()

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(10, 4))
sns.barplot(x=school_name_o, y=overall_rating, data=grouped_schools, palette='Set2', width=0.65)

plt.axhline(4.7,  linestyle='--', linewidth=2, label='Ironhack Average Rating')
plt.legend()

# Set labels and title
#plt.xticks(rotation=45, ha='right')
plt.xlabel('Overall Rating')
plt.ylabel('School Name')
plt.title('Top 5 Overall Rating by School')

plt.savefig('overall_rating_ih.png')

# Show plot
plt.show()

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(10, 4))
sns.barplot(x=school_name_c, y=curriculum_rating, data=grouped_schools, palette='Set2', width=0.65)

plt.axhline(4.7,  linestyle='--', linewidth=2, label='Ironhack Average Rating')
plt.legend()

# Set labels and title
#plt.xticks(rotation=45, ha='right')
plt.xlabel('Curiculum Rating')
plt.ylabel('School Name')
plt.title('Top 5 Curriculum Rating by School')

plt.savefig('curriculum_rating_ih.png')

# Show plot
plt.show()

# %%
tech_elevator = comments[comments['school']=='tech-elevator']
top_comments = tech_elevator[tech_elevator['jobSupport']==5]

# %%
top_comments['review_body'].sample(5)
# Out:
# 2      Initially skeptical about the effectiveness of...
# 124    I had a fantastic experience at Tech Elevator....
# 135    Let's be real... This is the best thing you co...
# 82     So if you're like me, prior to signing up for ...
# 216    Going to Tech Elevator was one of the best exp...
# Name: review_body, dtype: object

# %% [markdown]
# ---

# %%
grouped_comments = comments.groupby(['program_category', 'school']).agg({'id': 'count',
                                                               'jobSupport': 'mean',
                                                 'overallScore': 'mean',
                                                 'curriculum': 'mean'}).reset_index()
grouped_comments
# Out:
#          program_category            school   id  jobSupport  overallScore  \
# 0   Blockchain and Crypto         altcademy    2         NaN      4.750000
# 1   Blockchain and Crypto           udacity    2    5.000000      4.850000
# 2           Bootcamp Prep       app-academy   80    4.728814      4.703797
# 3           Bootcamp Prep         codesmith   44    4.772727      4.895455
# 4           Bootcamp Prep            nucamp    1    4.000000      4.300000
# ..                    ...               ...  ...         ...           ...
# 86        Web Development       springboard    1    5.000000      5.000000
# 87        Web Development     tech-elevator    4    5.000000      4.925000
# 88        Web Development  the-tech-academy    2    4.500000      4.850000
# 89        Web Development         tripleten   29    4.640000      4.865517
# 90        Web Development           udacity  182    4.022099      4.435714
#
#     curriculum
# 0     4.500000
# 1     4.500000
# 2     4.696203
# 3     4.886364
# 4     4.000000
# ..         ...
# 86    5.000000
# 87    4.750000
# 88    5.000000
# 89    4.931034
# 90    4.648352
#
# [91 rows x 6 columns]

# %%
ih_categories = grouped_comments[grouped_comments['school']=='ironhack']
ih_categories
# Out:
#         program_category    school   id  jobSupport  overallScore  curriculum
# 7          Cybersecurity  ironhack    9    4.222222      4.144444    4.111111
# 12        Data Analytics  ironhack   86    4.294118      4.404651    4.406977
# 37                 Other  ironhack   74    4.479452      4.564865    4.527027
# 58  Software Engineering  ironhack   23    4.869565      4.856522    4.869565
# 69          UX/UI Design  ironhack  323    4.606349      4.670588    4.656250
# 82       Web Development  ironhack  778    4.786198      4.814748    4.786577

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(10, 4))
sns.barplot(x='program_category', y='overallScore', data=ih_categories, palette='Set2', width=0.3)


# Set labels and title
#plt.xticks(rotation=45, ha='right')
plt.xlabel('Program Category')
plt.ylabel('Rating')
plt.title('Overall Rating of Ironhack Bootcamp per Category')

#plt.savefig('category_rating.png')

# Show plot
plt.show()

# %%
yearly_score = comments.groupby('graduatingYear').agg({'jobSupport': 'mean',
                                                 'overallScore': 'mean',
                                                 'curriculum': 'mean'}).reset_index()

# %%
yearly_score = yearly_score[yearly_score['graduatingYear'] != 0]

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(10, 4))
sns.lineplot(x='graduatingYear', y='overallScore', data=yearly_score, label='Overall Score')
sns.lineplot(x='graduatingYear', y='jobSupport', data=yearly_score, label='Job Support')
sns.lineplot(x='graduatingYear', y='curriculum', data=yearly_score, label='Curriculum')

# Manually set the tick locations and labels to show every value on the x-axis
plt.xticks(ticks=yearly_score['graduatingYear'], labels=yearly_score['graduatingYear'])

# Set labels and title
plt.xlabel('Graduating Year')
plt.ylabel('Rating')
plt.title('Yearly Average Rating of Ironhack')

# Add a legend
plt.legend()

# Adjust layout
plt.tight_layout()

plt.savefig('yearly_rating_ih.png')

# Show plot
plt.show()
